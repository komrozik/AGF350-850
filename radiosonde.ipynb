# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

# %%
df1 = pd.read_csv("radiosonde/2024-01-28_2056.raw_history.csv",sep=',\s+')
df1 = df1.dropna(axis=1, how='all')
# Out:
# /tmp/ipykernel_242363/2838108208.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df1 = pd.read_csv("radiosonde/2024-01-28_2056.raw_history.csv",sep=',\s+')

# %%
df1
# Out:
#      UTC time  Altitude (m MSL)  Altitude (m AGL)  Pressure (Pascal)  \
# 0    20:56:24                 8                 0              98146
# 1    20:56:29                 8                 0              98146
# 2    20:56:30                 8                 0              98146
# 3    20:56:31                 7                -1              98147
# 4    20:56:32                 7                -1              98148
# ..        ...               ...               ...                ...
# 743  21:18:41                 6                -2              98160
# 744  21:18:47                 7                -1              98156
# 745  21:18:53                 7                -1              98150
# 746  21:18:59                 8                 0              98136
# 747  21:19:05                 8                 0              98140
#
#      Speed (m/s)  Heading (degrees)  Temperature (C)  Relative humidity (%)  \
# ...
