# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("drone_data/flight_2_5s.csv")
df1 = df1.dropna(axis=1, how='all')

# %% [markdown]
# ## Drone Tags

# %% [markdown]
# drone25_time

# %% [markdown]
# ### CTUN

# %% [markdown]
# drone25_CTUN_ThI, drone25_CTUN_ABst, drone25_CTUN_ThO, drone25_CTUN_ThH, drone25_CTUN_DAlt, drone25_CTUN_Alt, drone25_CTUN_BAlt, drone25_CTUN_SAlt, drone25_CTUN_DCRt, drone25_CTUN_CRt

# %% [markdown]
# ### FTN

# %% [markdown]
# drone25_FTN_NDn
# drone25_FTN_DnF1
# drone25_FTN_DnF2
# drone25_FTN_DnF3
# drone25_FTN_DnF4

# %% [markdown]
# ### DU32

# %% [markdown]
# drone25_DU32_Id
# drone25_DU32_Value

# %% [markdown]
# ### TERR
# drone25_TERR_Status
# drone25_TERR_Lat
# drone25_TERR_Lng
# drone25_TERR_Spacing
# drone25_TERR_TerrH
# drone25_TERR_CHeight
# drone25_TERR_Pending
# drone25_TERR_Loaded
# ### ATT
# drone25_ATT_DesRoll
# drone25_ATT_Roll
# drone25_ATT_DesPitch
# drone25_ATT_Pitch
# drone25_ATT_DesYaw
# drone25_ATT_Yaw
# drone25_ATT_ErrRP
# drone25_ATT_ErrYaw
# drone25_ATT_AEKF
# ### RATE
# drone25_RATE_RDes
# drone25_RATE_R
# drone25_RATE_ROut
# drone25_RATE_PDes
# drone25_RATE_P
# drone25_RATE_POut
# drone25_RATE_YDes
# drone25_RATE_Y
# drone25_RATE_YOut
# drone25_RATE_ADes
# drone25_RATE_A
# drone25_RATE_AOut
# ### XKF1
# drone25_XKF1_C
# drone25_XKF1_Roll
# drone25_XKF1_Pitch
# drone25_XKF1_Yaw
# drone25_XKF1_VN
# drone25_XKF1_VE
# drone25_XKF1_VD
# drone25_XKF1_dPD
# drone25_XKF1_PN
# drone25_XKF1_PE
# drone25_XKF1_PD
# drone25_XKF1_GX
# drone25_XKF1_GY
# drone25_XKF1_GZ
# drone25_XKF1_OH
# ### XKF2
# drone25_XKF2_C
# drone25_XKF2_AX
# drone25_XKF2_AY
# drone25_XKF2_AZ
# drone25_XKF2_VWN
# drone25_XKF2_VWE
# drone25_XKF2_MN
# drone25_XKF2_ME
# drone25_XKF2_MD
# drone25_XKF2_MX
# drone25_XKF2_MY
# drone25_XKF2_MZ
# drone25_XKF2_IDX
# drone25_XKF2_IDY
# drone25_XKF2_IS
# ### XKF3
# drone25_XKF3_C
# drone25_XKF3_IVN
# drone25_XKF3_IVE
# drone25_XKF3_IVD
# drone25_XKF3_IPN
# drone25_XKF3_IPE
# drone25_XKF3_IPD
# drone25_XKF3_IMX
# drone25_XKF3_IMY
# drone25_XKF3_IMZ
# drone25_XKF3_IYAW
# drone25_XKF3_IVT
# drone25_XKF3_RErr
# drone25_XKF3_ErSc
# ### XKF4
# drone25_XKF4_C
# drone25_XKF4_SV
# drone25_XKF4_SP
# drone25_XKF4_SH
# drone25_XKF4_SM
# drone25_XKF4_SVT
# drone25_XKF4_errRP
# drone25_XKF4_OFN
# drone25_XKF4_OFE
# drone25_RCOU_C8
# drone25_RCOU_C9
# drone25_RCOU_C10
# drone25_RCOU_C11
# drone25_RCOU_C12
# drone25_RCOU_C13
# drone25_RCOU_C14
# ### PSCN
# drone25_PSCN_TPN
# drone25_PSCN_PN
# drone25_PSCN_DVN
# drone25_PSCN_TVN
# drone25_PSCN_VN
# drone25_PSCN_DAN
# drone25_PSCN_TAN
# drone25_PSCN_AN
# ### PSCE
# drone25_PSCE_TPE
# drone25_PSCE_PE
# drone25_PSCE_DVE
# drone25_PSCE_TVE
# drone25_PSCE_VE
# drone25_PSCE_DAE
# drone25_PSCE_TAE
# drone25_PSCE_AE
# ### PSCD
# drone25_PSCD_TPD
# drone25_PSCD_PD
# drone25_PSCD_DVD
# drone25_PSCD_TVD
# drone25_PSCD_VD
# drone25_PSCD_DAD
# drone25_PSCD_TAD
# drone25_PSCD_AD
# ### VIBE
# drone25_VIBE_IMU
# drone25_VIBE_VibeX
# drone25_VIBE_VibeY
# drone25_VIBE_VibeZ
# drone25_VIBE_Clip
# ### CTRL
# drone25_CTRL_RMSRollP
# drone25_CTRL_RMSRollD
# drone25_CTRL_RMSPitchP
# drone25_CTRL_RMSPitchD
# drone25_CTRL_RMSYaw
# ### IMU
# drone25_IMU_I
# drone25_IMU_GyrX
# drone25_IMU_GyrY
# drone25_IMU_GyrZ
# drone25_IMU_AccX
# drone25_IMU_AccY
# drone25_IMU_AccZ
# drone25_IMU_EG
# drone25_IMU_EA
# drone25_IMU_T
# drone25_IMU_GH
# drone25_IMU_AH
# drone25_IMU_GHz
# drone25_IMU_AHz
# ### CMD
# drone25_CMD_CTot
# drone25_CMD_CNum
# drone25_CMD_CId
# drone25_CMD_Prm1
# drone25_CMD_Prm2
# drone25_CMD_Prm3
# drone25_CMD_Prm4
# drone25_CMD_Lat
# drone25_CMD_Lng
# drone25_CMD_Alt
# drone25_CMD_Frame
# ### EV
# drone25_EV_Id
# ### DSF
# drone25_DSF_Dp
# drone25_DSF_Blk
# drone25_DSF_Bytes
# drone25_DSF_FMn
# drone25_DSF_FMx
# drone25_DSF_FAv
# ### POWR
# drone25_POWR_Vcc
# drone25_POWR_VServo
# drone25_POWR_Flags
# drone25_POWR_AccFlags
# drone25_POWR_Safety
# ### BAT
# drone25_BAT_Instance
# drone25_BAT_Volt
# drone25_BAT_VoltR
# drone25_BAT_Curr
# drone25_BAT_CurrTot
# drone25_BAT_EnrgTot
# drone25_BAT_Temp
# drone25_BAT_Res
# drone25_BAT_RemPct
# ### MAG
# drone25_MAG_I
# drone25_MAG_MagX
# drone25_MAG_MagY
# drone25_MAG_MagZ
# drone25_MAG_OfsX
# drone25_MAG_OfsY
# drone25_MAG_OfsZ
# drone25_MAG_MOX
# drone25_MAG_MOY
# drone25_MAG_MOZ
# drone25_MAG_Health
# drone25_MAG_S
# ### BARO
# drone25_BARO_I
# drone25_BARO_Alt
# drone25_BARO_Press
# drone25_BARO_Temp
# drone25_BARO_CRt
# drone25_BARO_SMS
# drone25_BARO_Offset
# drone25_BARO_GndTemp
# drone25_BARO_Health
# ### ARM
# drone25_ARM_ArmState
# drone25_ARM_ArmChecks
# drone25_ARM_Forced
# drone25_ARM_Method
# ### ERR
# drone25_ERR_Subsys
# drone25_ERR_ECode
#
# ### General
# drone25_alt
# drone25_roll
# drone25_pitch
# drone25_heading_yaw
# drone25_tilt_angle
# drone25_current.alt
# drone25_rho
# drone25_baro_pressure_pa
# drone25_lon
# drone25_lat
# drone25_z
# drone25_on_alt_setpoint_bool
# drone25_is_on_alt_level
# drone25_level
# drone25_WS_from_tilt
# drone25_WD_from_tilt
# drone25_u_from_tilt
# drone25_v_from_tilt
# drone25_sbaT
# drone25_sbaH
# drone25_sbaP
# drone25_mpcT
# drone25_scdCO2
# drone25_scdT
# drone25_scdH
# drone25_bmeT
# drone25_bmeH
# drone25_bmeP
# drone25_bmeA
# drone25_mlxAmbT
# drone25_mlxObjT
# drone25_VRL_F2600
# drone25_ppm_CH4
# drone25_Rs_F2600
# drone25_mpcTemp
# drone25_mpcTemp_pot
# drone25_bmeT_pot
# drone25_saturation_vapor_pressure_bme
# drone25_vapor_pressure_bme
# drone25_specific_humidity_bme
# drone25_esat_hPa
# drone25_vapor_pressure_hPa
# drone25_abs_humidity

# %% [markdown]
# ## Code

# %% [markdown]
# **Norberts recommended Tags:**

# %%
fig, ax = plt.subplots(5,figsize = (10,10),dpi = 300,tight_layout = True)
fig.suptitle('Coast Transect')
ax[0].plot(df1["drone25_alt"],marker = ".")
ax[1].plot(df1["drone25_mpcTemp"], label = "Temp")
ax[1].plot(df1["drone25_mpcTemp_pot"], label = "potential Temp")
ax[1].legend()
ax[3].plot(df1["drone25_specific_humidity_bme"])
ax[4].plot(df1["drone25_scdCO2"])

# %%
plt.scatter(df1["drone25_mpcTemp"][0:240],df1["drone25_CTUN_Alt"][0:240],label = "First Transect")
plt.scatter(df1["drone25_mpcTemp"][241::],df1["drone25_CTUN_Alt"][241::],label = "Second Transect")
plt.xlabel("Temperature [°C]")
plt.ylabel("Height [m]")
plt.title("Temperature")
plt.legend()

# %%
plt.scatter(df1["drone25_mpcTemp_pot"][0:240],df1["drone25_CTUN_Alt"][0:240],label = "First Transect")
plt.scatter(df1["drone25_mpcTemp_pot"][241::],df1["drone25_CTUN_Alt"][241::],label = "Second Transect")
plt.xlabel("Potential Temperature [°C]")
plt.ylabel("Height [m]")
plt.title("Potential Temperature")
plt.legend()

# %%
plt.scatter(df1["drone25_abs_humidity"][0:240],df1["drone25_CTUN_Alt"][0:240],label = "First Transect")
plt.scatter(df1["drone25_abs_humidity"][241::],df1["drone25_CTUN_Alt"][241::],label = "Second Transect")
plt.xlabel("Humidity")
plt.ylabel("Height [m]")
plt.title("Absolute Humidity")
plt.legend()

# %%
plt.scatter(df1["drone25_scdCO2"][0:240],df1["drone25_CTUN_Alt"][0:240],label = "First Transect")
plt.scatter(df1["drone25_scdCO2"][241::],df1["drone25_CTUN_Alt"][241::],label = "Second Transect")
plt.xlabel("CO2")
plt.ylabel("Height [m]")
plt.title("CO2")
plt.legend(loc = "best")

# %%
df1["drone25_alt"]
